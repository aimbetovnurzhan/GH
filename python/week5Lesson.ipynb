# %%
j = 0 
for i in range(0,1000,7):
    # if i > 100:
        # print(j,'---', i) 
    j += 1 

a = 0
b = 0

while a < 1000:
    if a > 100:
        print(b, '----', a)
    b += 1
    a += 7
else:
    print('Цикл окончен')
# Out:
# 15 ---- 105
# 16 ---- 112
# 17 ---- 119
# 18 ---- 126
# 19 ---- 133
# 20 ---- 140
# 21 ---- 147
# 22 ---- 154
# 23 ---- 161
# 24 ---- 168
# 25 ---- 175
# 26 ---- 182
# 27 ---- 189
# 28 ---- 196
# 29 ---- 203
# 30 ---- 210
# 31 ---- 217
# 32 ---- 224
# 33 ---- 231
# 34 ---- 238
# 35 ---- 245
# 36 ---- 252
# 37 ---- 259
# 38 ---- 266
# 39 ---- 273
# 40 ---- 280
# 41 ---- 287
# 42 ---- 294
# 43 ---- 301
# 44 ---- 308
# 45 ---- 315
# 46 ---- 322
# 47 ---- 329
# 48 ---- 336
# 49 ---- 343
# 50 ---- 350
# 51 ---- 357
# 52 ---- 364
# 53 ---- 371
# 54 ---- 378
# 55 ---- 385
# 56 ---- 392
# 57 ---- 399
# 58 ---- 406
# 59 ---- 413
# 60 ---- 420
# 61 ---- 427
# 62 ---- 434
# 63 ---- 441
# 64 ---- 448
# 65 ---- 455
# 66 ---- 462
# 67 ---- 469
# 68 ---- 476
# 69 ---- 483
# 70 ---- 490
# 71 ---- 497
# 72 ---- 504
# 73 ---- 511
# 74 ---- 518
# 75 ---- 525
# 76 ---- 532
# 77 ---- 539
# 78 ---- 546
# 79 ---- 553
# 80 ---- 560
# 81 ---- 567
# 82 ---- 574
# 83 ---- 581
# 84 ---- 588
# 85 ---- 595
# ...
