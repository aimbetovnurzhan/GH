# %%
"""j = 0 
for i in range(0,1000,7):
    # if i > 100:
        # print(j,'---', i) 
    j += 1 

a = 0
b = 0

while a < 1000:
    if a > 100:
        print(b, '----', a)
    b += 1
    a += 7
else:
    print('Цикл окончен')
"""

for i, j in enumerate(range(0,1000,7)[:], start=1):
    if j > 100:
        print(i, '===', j)
# Out:
# 16 === 105
# 17 === 112
# 18 === 119
# 19 === 126
# 20 === 133
# 21 === 140
# 22 === 147
# 23 === 154
# 24 === 161
# 25 === 168
# 26 === 175
# 27 === 182
# 28 === 189
# 29 === 196
# 30 === 203
# 31 === 210
# 32 === 217
# 33 === 224
# 34 === 231
# 35 === 238
# 36 === 245
# 37 === 252
# 38 === 259
# 39 === 266
# 40 === 273
# 41 === 280
# 42 === 287
# 43 === 294
# 44 === 301
# 45 === 308
# 46 === 315
# 47 === 322
# 48 === 329
# 49 === 336
# 50 === 343
# 51 === 350
# 52 === 357
# 53 === 364
# 54 === 371
# 55 === 378
# 56 === 385
# 57 === 392
# 58 === 399
# 59 === 406
# 60 === 413
# 61 === 420
# 62 === 427
# 63 === 434
# 64 === 441
# 65 === 448
# 66 === 455
# 67 === 462
# 68 === 469
# 69 === 476
# 70 === 483
# 71 === 490
# 72 === 497
# 73 === 504
# 74 === 511
# 75 === 518
# 76 === 525
# 77 === 532
# 78 === 539
# 79 === 546
# 80 === 553
# 81 === 560
# 82 === 567
# 83 === 574
# 84 === 581
# 85 === 588
# 86 === 595
# 87 === 602
# 88 === 609
# 89 === 616
# 90 === 623
# 91 === 630
# ...
