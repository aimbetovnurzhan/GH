# %%
#Сделать калькулятор, ввести общую сумму чека, кол-во людей (имена людей) и сумму чаевых.
#В итоге нужно вернуть  тотал сумму чека, сумму чаевых.
# Дальше разделить чек по именам с суммами на каждого, чаевые и тотал на каждого.

print('введите сумму чека:')
s=float(input())

print('количество гостей:')
c=int(input())

eachBillAmnt = s/c
totalTips=0

if c>1:
    tipsList=[]
    for i in range(c):
        print('введите сумму чаевых гостя №' + str(i+1) + ' :')
        tip = float(input())
        print('Гост № %d.\n Доля суммы к оплате: $%0.2f.\n Tips: $%0.2f.\n Общая сумма к оплате: $ %0.2f.' %  (i+1, eachBillAmnt, tip, eachBillAmnt + tip))
        totalTips += tip
        print('TotalTips: $%0.2f.\nОбщая сумма к оплате: $ %0.2f.' %  (totalTips, s + totalTips))
else:
    print('введите сумма чаевых:')
    totalTips = float(input())
    print('Tips: $%0.2f.\nОбщая сумма к оплате: $ %0.2f.' %  (totalTips, s + totalTips))
# Out:
# введите сумму чека:
# 250
# количество гостей:
# 1
# введите сумма чаевых:
# 25
# Tips: $25.00.
#  Общая сумма к оплате: $ 275.00.

# %%
# A. match_ends
# Given a list of strings, return the count of the number of
# strings where the string length is 2 or more and the first
# and last chars of the string are the same.
# Note: python does not have a ++ operator, but += works.
def match_ends(words):
    # +++your code here+++
    j = 0
    for i in range(len(words)):
        if len(words[i]) >= 2 and words[i][0] == words[i][-1]:
            j += 1
    return j

# B. front_x
# Given a list of strings, return a list with the strings
# in sorted order, except group all the strings that begin with 'x' first.
# e.g. ['mix', 'xyz', 'apple', 'xanadu', 'aardvark'] yields
# ['xanadu', 'xyz', 'aardvark', 'apple', 'mix']
# Hint: this can be done by making 2 lists and sorting each of them
# before combining them.
def front_x(words):
    # +++your code here+++
    k, l = 0, 0
    n = len(words)
    for k in range(n-1):
        for l in range(k+1, n):
            if words[k] > words[l]:
                words[k], words[l] = words[l], words[k]
    l = 0
    for k in range(n):
        if words[k].startswith("x"):
            words.insert(0+l,words[k])
            l += 1
            words.pop(k+1)
    return words

# C. sort_last
# Given a list of non-empty tuples, return a list sorted in increasing
# order by the last element in each tuple.
# e.g. [(1, 7), (1, 3), (3, 4, 5), (2, 2)] yields
# [(2, 2), (1, 3), (3, 4, 5), (1, 7)]
# Hint: use a custom key= function to extract the last element form each tuple.
def sort_last(tuples):
    # +++your code here+++
    n = len(tuples)
    for i in range(n):
        for j in range(i+1,n):
            if tuples[i][-1] > tuples[j][-1]:
                tuples[i], tuples[j] = tuples[j], tuples[i]
    return tuples


# Simple provided test() function used in main() to print
# what each function returns vs. what it's supposed to return.
def test(got, expected):
    if got == expected:
        prefix = ' OK '
    else:
        prefix = '  X '
    print('%s got: %s expected: %s' % (prefix, repr(got), repr(expected)))


# Calls the above functions with interesting inputs.
def main():
  print('match_ends')
  test(match_ends(['aba', 'xyz', 'aa', 'x', 'bbb']), 3)
  test(match_ends(['', 'x', 'xy', 'xyx', 'xx']), 2)
  test(match_ends(['aaa', 'be', 'abc', 'hello']), 1)

  print()
  print('front_x')
  test(front_x(['bbb', 'ccc', 'axx', 'xzz', 'xaa']),
       ['xaa', 'xzz', 'axx', 'bbb', 'ccc'])
  test(front_x(['ccc', 'bbb', 'aaa', 'xcc', 'xaa']),
       ['xaa', 'xcc', 'aaa', 'bbb', 'ccc'])
  test(front_x(['mix', 'xyz', 'apple', 'xanadu', 'aardvark']),
       ['xanadu', 'xyz', 'aardvark', 'apple', 'mix'])


  print()
  print('sort_last')
  test(sort_last([(1, 3), (3, 2), (2, 1)]),
       [(2, 1), (3, 2), (1, 3)])
  test(sort_last([(2, 3), (1, 2), (3, 1)]),
       [(3, 1), (1, 2), (2, 3)])
  test(sort_last([(1, 7), (1, 3), (3, 4, 5), (2, 2)]),
       [(2, 2), (1, 3), (3, 4, 5), (1, 7)])

main()
# Out:
# match_ends
#  OK  got: 3 expected: 3
#  OK  got: 2 expected: 2
#  OK  got: 1 expected: 1
#
# front_x
#  OK  got: ['xaa', 'xzz', 'axx', 'bbb', 'ccc'] expected: ['xaa', 'xzz', 'axx', 'bbb', 'ccc']
#  OK  got: ['xaa', 'xcc', 'aaa', 'bbb', 'ccc'] expected: ['xaa', 'xcc', 'aaa', 'bbb', 'ccc']
#  OK  got: ['xanadu', 'xyz', 'aardvark', 'apple', 'mix'] expected: ['xanadu', 'xyz', 'aardvark', 'apple', 'mix']
#
# sort_last
#  OK  got: [(2, 1), (3, 2), (1, 3)] expected: [(2, 1), (3, 2), (1, 3)]
#  OK  got: [(3, 1), (1, 2), (2, 3)] expected: [(3, 1), (1, 2), (2, 3)]
#  OK  got: [(2, 2), (1, 3), (3, 4, 5), (1, 7)] expected: [(2, 2), (1, 3), (3, 4, 5), (1, 7)]

# %%
words = ['bbb', 'ccc', 'axx', 'xzz', 'xaa']
k, l = 0, 0
n = len(words)
for k in range(n-1):
    print(k)
    for l in range(k+1, n):
        print(" ",l,words)
        if words[k] > words[l]:
            words[k], words[l] = words[l], words[k]
            print(" ",l,words,"TRUE")
    print('------------------------------------')
l = 0
for k in range(n):
    print(k)
    if words[k].startswith("x"):
        print(l, words)
        words.insert(0+l,words[k])
        l += 1
        print(l, words)
        words.pop(k+1)
        print(l, words)
# Out:
# 0
#   1 ['bbb', 'ccc', 'axx', 'xzz', 'xaa']
#   2 ['bbb', 'ccc', 'axx', 'xzz', 'xaa']
#   2 ['axx', 'ccc', 'bbb', 'xzz', 'xaa'] TRUE
#   3 ['axx', 'ccc', 'bbb', 'xzz', 'xaa']
#   4 ['axx', 'ccc', 'bbb', 'xzz', 'xaa']
# ------------------------------------
# 1
#   2 ['axx', 'ccc', 'bbb', 'xzz', 'xaa']
#   2 ['axx', 'bbb', 'ccc', 'xzz', 'xaa'] TRUE
#   3 ['axx', 'bbb', 'ccc', 'xzz', 'xaa']
#   4 ['axx', 'bbb', 'ccc', 'xzz', 'xaa']
# ------------------------------------
# 2
#   3 ['axx', 'bbb', 'ccc', 'xzz', 'xaa']
#   4 ['axx', 'bbb', 'ccc', 'xzz', 'xaa']
# ------------------------------------
# 3
#   4 ['axx', 'bbb', 'ccc', 'xzz', 'xaa']
#   4 ['axx', 'bbb', 'ccc', 'xaa', 'xzz'] TRUE
# ------------------------------------
# 0
# 1
# 2
# 3
# 0 ['axx', 'bbb', 'ccc', 'xaa', 'xzz']
# 1 ['xaa', 'axx', 'bbb', 'ccc', 'xaa', 'xzz']
# 1 ['xaa', 'axx', 'bbb', 'ccc', 'xzz']
# 4
# 1 ['xaa', 'axx', 'bbb', 'ccc', 'xzz']
# 2 ['xaa', 'xzz', 'axx', 'bbb', 'ccc', 'xzz']
# 2 ['xaa', 'xzz', 'axx', 'bbb', 'ccc']

# %%
tuples=[(1, 3), (3, 2), (2, 1)]
print(tuples[0][-1])
# Out:
# 3
